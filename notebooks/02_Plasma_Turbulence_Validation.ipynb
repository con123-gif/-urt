# %%
import sys
sys.path.append('/content/lytolllis-chaos-lab')
from src.lytollis_unified import plasma_surrogate, lle_rosenstein, DKY_from_lle, avalanche_tau
ts = plasma_surrogate()
lle=lle_rosenstein(ts)
D=DKY_from_lle(lle)
tau=avalanche_tau(ts, q=0.75)
print({'LLE':lle,'D_KY':D,'tau':tau})
